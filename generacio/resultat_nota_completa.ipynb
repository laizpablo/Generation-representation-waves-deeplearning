# %%
import helper as hp
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
dir_folder='./'
files = hp.find_generation(dir_folder)
print len(files)
# Out:
# 57

# %%
_list = [(hp.load_generic_audio(_file),_file) for _file in files]

# %%
hp.show_one_complete_audio(_list[0][0],8000)
